# %% [markdown]
# <a href="https://colab.research.google.com/github/sonivarun01/ai-ml-colab-projects/blob/main/GridSearchCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import (
    KFold,
    RepeatedKFold,
    LeaveOneOut,
    LeavePOut,
    StratifiedKFold,
    GridSearchCV,
    train_test_split
)

# %%
X, y = load_breast_cancer(return_X_y=True, as_frame=True)

# %%
y = y.map({0:1, 1:0})

# %%
X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
X_train.shape, X_test.shape
# Out:
# ((398, 30), (171, 30))

# %%
logit = LogisticRegression(penalty='l2',C=1, solver='liblinear',random_state=4, max_iter=10000)
kf = KFold(n_splits=5, shuffle=True, random_state=4)
#hyperparameter space
param_grid = dict(
    penalty=['l1','l2'],
    C = [0.1,1,10]
)

#K-Fold Cross_Validation
clf = GridSearchCV(
    logit,
    param_grid,
    scoring='accuracy',
    cv=kf,
    refit = True
)

search = clf.fit(X_train,y_train)
search.best_params_
# Out:
# {'C': 10, 'penalty': 'l2'}

# %%
results = pd.DataFrame(search.cv_results_) [['params','mean_test_score','std_test_score']]
print(results.shape)
results
# Out:
# (6, 3)
#                         params  mean_test_score  std_test_score
# 0  {'C': 0.1, 'penalty': 'l1'}         0.919620        0.012606
# 1  {'C': 0.1, 'penalty': 'l2'}         0.934747        0.019812
# 2    {'C': 1, 'penalty': 'l1'}         0.944810        0.024360
# 3    {'C': 1, 'penalty': 'l2'}         0.944778        0.025651
# 4   {'C': 10, 'penalty': 'l1'}         0.947247        0.014592
# 5   {'C': 10, 'penalty': 'l2'}         0.949778        0.013609

# %%
results.sort_values(by='mean_test_score',ascending=False,inplace=True)

results.reset_index(drop=True,inplace=True)

results['mean_test_score'].plot(yerr = [results['std_test_score'],results['std_test_score']],subplots=True)
plt.ylabel('Mean Accuracy')
plt.xlabel('Hyperparameter Space')
# Out:
# Text(0.5, 0, 'Hyperparameter Space')

# %%
train_preds = search.predict(X_train)
test_preds = search.predict(X_test)

print('Train Accuracy: ', accuracy_score(y_train,train_preds))
print('Test Accuracy: ', accuracy_score(y_test,test_preds))
# Out:
# Train Accuracy:  0.9623115577889447
# Test Accuracy:  0.9532163742690059

# %%
#Repeated K-Folds
logit = LogisticRegression(penalty='l2',C=1, solver='liblinear',random_state=4, max_iter=10000)
rkf = RepeatedKFold(n_splits=5, n_repeats=10, random_state=4)
#hyperparameter space
param_grid = dict(
    penalty=['l1','l2'],
    C = [0.1,1,10]
)

#Repeated K-Fold Cross_Validation
clf = GridSearchCV(
    logit,
    param_grid,
    scoring='accuracy',
    cv=rkf,
    refit = True
)

search = clf.fit(X_train,y_train)
search.best_params_
# Out:
# {'C': 10, 'penalty': 'l1'}

# %%
results = pd.DataFrame(search.cv_results_) [['params','mean_test_score','std_test_score']]
print(results.shape)
results
# Out:
# (6, 3)
#                         params  mean_test_score  std_test_score
# 0  {'C': 0.1, 'penalty': 'l1'}         0.922820        0.022496
# 1  {'C': 0.1, 'penalty': 'l2'}         0.932896        0.021612
# 2    {'C': 1, 'penalty': 'l1'}         0.948497        0.021488
# 3    {'C': 1, 'penalty': 'l2'}         0.945968        0.022963
# 4   {'C': 10, 'penalty': 'l1'}         0.955025        0.023470
# 5   {'C': 10, 'penalty': 'l2'}         0.951759        0.024031

# %%
results.sort_values(by='mean_test_score',ascending=False,inplace=True)

results.reset_index(drop=True,inplace=True)

results['mean_test_score'].plot(yerr = [results['std_test_score'],results['std_test_score']],subplots=True)
plt.ylabel('Mean Accuracy')
plt.xlabel('Hyperparameter Space')
# Out:
# Text(0.5, 0, 'Hyperparameter Space')

# %%
train_preds = search.predict(X_train)
test_preds = search.predict(X_test)

print('Train Accuracy: ', accuracy_score(y_train,train_preds))
print('Test Accuracy: ', accuracy_score(y_test,test_preds))
# Out:
# Train Accuracy:  0.9748743718592965
# Test Accuracy:  0.9707602339181286

# %%
#Leave One Out
logit = LogisticRegression(penalty='l2',C=1, solver='liblinear',random_state=4, max_iter=10000)
#hyperparameter space
param_grid = dict(
    penalty=['l1','l2'],
    C = [0.1,1,10]
)

loo = LeaveOneOut()
clf = GridSearchCV(
    logit,
    param_grid,
    scoring='accuracy',
    cv=loo,
    refit = True
)

search = clf.fit(X_train,y_train)
search.best_params_
# Out:
# {'C': 10, 'penalty': 'l1'}

# %%
results = pd.DataFrame(search.cv_results_) [['params','mean_test_score','std_test_score']]
print(results.shape)
results
# Out:
# (6, 3)
#                         params  mean_test_score  std_test_score
# 0  {'C': 0.1, 'penalty': 'l1'}         0.927136        0.259914
# 1  {'C': 0.1, 'penalty': 'l2'}         0.934673        0.247101
# 2    {'C': 1, 'penalty': 'l1'}         0.949749        0.218463
# 3    {'C': 1, 'penalty': 'l2'}         0.944724        0.228519
# 4   {'C': 10, 'penalty': 'l1'}         0.959799        0.196430
# 5   {'C': 10, 'penalty': 'l2'}         0.957286        0.202211

# %%
results.sort_values(by='mean_test_score',ascending=False,inplace=True)

results.reset_index(drop=True,inplace=True)

results['mean_test_score'].plot(yerr = [results['std_test_score'],results['std_test_score']],subplots=True)
plt.ylabel('Mean Accuracy')
plt.xlabel('Hyperparameter Space')
# Out:
# Text(0.5, 0, 'Hyperparameter Space')

# %%
train_preds = search.predict(X_train)
test_preds = search.predict(X_test)

print('Train Accuracy: ', accuracy_score(y_train,train_preds))
print('Test Accuracy: ', accuracy_score(y_test,test_preds))
# Out:
# Train Accuracy:  0.9748743718592965
# Test Accuracy:  0.9707602339181286

# %%
#Leave P Out
logit = LogisticRegression(penalty='l2',C=1, solver='liblinear',random_state=4, max_iter=10000)
#hyperparameter space
param_grid = dict(
    penalty=['l1','l2'],
    C = [0.1,1,10]
)

lpo = LeavePOut(p=2)
X_train_small = X_train.head(30)
y_train_small = y_train.head(30)

clf = GridSearchCV(
    logit,
    param_grid,
    scoring='accuracy',
    cv=lpo,
    refit = True
)

search = clf.fit(X_train_small,y_train_small)
search.best_params_
# Out:
# {'C': 0.1, 'penalty': 'l1'}

# %%
results = pd.DataFrame(search.cv_results_) [['params','mean_test_score','std_test_score']]
print(results.shape)
results
# Out:
# (6, 3)
#                         params  mean_test_score  std_test_score
# 0  {'C': 0.1, 'penalty': 'l1'}         0.900000        0.208443
# 1  {'C': 0.1, 'penalty': 'l2'}         0.898851        0.209265
# 2    {'C': 1, 'penalty': 'l1'}         0.870115        0.226982
# 3    {'C': 1, 'penalty': 'l2'}         0.872414        0.225750
# 4   {'C': 10, 'penalty': 'l1'}         0.870115        0.226982
# 5   {'C': 10, 'penalty': 'l2'}         0.870115        0.226982

# %%
results.sort_values(by='mean_test_score',ascending=False,inplace=True)

results.reset_index(drop=True,inplace=True)

results['mean_test_score'].plot(yerr = [results['std_test_score'],results['std_test_score']],subplots=True)
plt.ylabel('Mean Accuracy')
plt.xlabel('Hyperparameter Space')
# Out:
# Text(0.5, 0, 'Hyperparameter Space')

# %%
train_preds = search.predict(X_train)
test_preds = search.predict(X_test)

print('Train Accuracy: ', accuracy_score(y_train,train_preds))
print('Test Accuracy: ', accuracy_score(y_test,test_preds))
# Out:
# Train Accuracy:  0.9120603015075377
# Test Accuracy:  0.9239766081871345

# %%
# Stratified K-Fold CV
logit = LogisticRegression(penalty='l2',C=1, solver='liblinear',random_state=4, max_iter=10000)
#hyperparameter space
param_grid = dict(
    penalty=['l1','l2'],
    C = [0.1,1,10]
)

skf = StratifiedKFold(n_splits=5, shuffle=True,random_state=4)

clf = GridSearchCV(
    logit,
    param_grid,
    scoring='accuracy',
    cv=skf,
    refit = True
)

search = clf.fit(X_train_small,y_train_small)
search.best_params_
# Out:
# {'C': 0.1, 'penalty': 'l1'}

# %%
results = pd.DataFrame(search.cv_results_) [['params','mean_test_score','std_test_score']]
print(results.shape)
results
# Out:
# (6, 3)
#                         params  mean_test_score  std_test_score
# 0  {'C': 0.1, 'penalty': 'l1'}         0.933333        0.133333
# 1  {'C': 0.1, 'penalty': 'l2'}         0.933333        0.133333
# 2    {'C': 1, 'penalty': 'l1'}         0.900000        0.133333
# 3    {'C': 1, 'penalty': 'l2'}         0.900000        0.133333
# 4   {'C': 10, 'penalty': 'l1'}         0.900000        0.133333
# 5   {'C': 10, 'penalty': 'l2'}         0.900000        0.133333

# %%
results.sort_values(by='mean_test_score',ascending=False,inplace=True)

results.reset_index(drop=True,inplace=True)

results['mean_test_score'].plot(yerr = [results['std_test_score'],results['std_test_score']],subplots=True)
plt.ylabel('Mean Accuracy')
plt.xlabel('Hyperparameter Space')
# Out:
# Text(0.5, 0, 'Hyperparameter Space')

# %%
train_preds = search.predict(X_train)
test_preds = search.predict(X_test)

print('Train Accuracy: ', accuracy_score(y_train,train_preds))
print('Test Accuracy: ', accuracy_score(y_test,test_preds))
# Out:
# Train Accuracy:  0.9120603015075377
# Test Accuracy:  0.9239766081871345
